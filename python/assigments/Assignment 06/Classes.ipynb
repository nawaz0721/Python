# %% [markdown]
# ### Classes

# %% [markdown]
# 1- Write a Python program to create a class representing a Circle. Include methods to calculate its area and perimeter.

# %%
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius
    
    def calculate_area(self):
        """Calculate the area of the circle"""
        return math.pi * self.radius ** 2
    
    def calculate_perimeter(self):
        """Calculate the perimeter (circumference) of the circle"""
        return 2 * math.pi * self.radius

# Example usage
circle = Circle(5)
print(f"Circle with radius {circle.radius}:")
print(f"Area: {circle.calculate_area():.2f}")
print(f"Perimeter: {circle.calculate_perimeter():.2f}")
# Out:
# Circle with radius 5:
# Area: 78.54
# Perimeter: 31.42

# %% [markdown]
# 2- Write a Python program to create a person class. Include attributes like name, country and date of birth. Implement a method to determine the person's age.

# %%
from datetime import datetime, date

class Person:
    def __init__(self, name, country, date_of_birth):
        self.name = name
        self.country = country
        self.date_of_birth = date_of_birth
    
    def calculate_age(self):
        """Calculate the person's age based on date of birth"""
        today = date.today()
        age = today.year - self.date_of_birth.year
        
        # Check if birthday has occurred this year
        if today.month < self.date_of_birth.month or (today.month == self.date_of_birth.month and today.day < self.date_of_birth.day):
            age -= 1
        
        return age
    
    def display_info(self):
        """Display person's information"""
        age = self.calculate_age()
        print(f"Name: {self.name}")
        print(f"Country: {self.country}")
        print(f"Date of Birth: {self.date_of_birth}")
        print(f"Age: {age} years")

# Example usage
person1 = Person("Ahmed Nawaz Gondal", "Pakistan", date(2002, 1, 31))
person1.display_info()

print("\n" + "="*25)

person2 = Person("Muhammad Hashim", "Pakistan", date(2012, 6, 23))
person2.display_info()
# Out:
# Name: Ahmed Nawaz Gondal
# Country: Pakistan
# Date of Birth: 2002-01-31
# Age: 23 years
#
# ...
# Name: Muhammad Hashim
# Country: Pakistan
# Date of Birth: 2012-06-23
# Age: 13 years

# %% [markdown]
# 3- Write a Python program to create a calculator class. Include methods for basic arithmetic operations.

# %%
class Calculator:
    def __init__(self):
        self.result = 0
    
    def add(self, a, b):
        """Add two numbers"""
        return a + b
    
    def subtract(self, a, b):
        """Subtract second number from first number"""
        return a - b
    
    def multiply(self, a, b):
        """Multiply two numbers"""
        return a * b
    
    def divide(self, a, b):
        """Divide first number by second number"""
        if b == 0:
            return "Error: Division by zero is not allowed"
        return a / b
    
    def power(self, base, exponent):
        """Calculate base raised to the power of exponent"""
        result = 1
        for _ in range(exponent):
            result *= base
        return result
    
    def display_operations(self, a, b):
        """Display all operations for two numbers"""
        print(f"\nOperations for {a} and {b}:")
        print(f"Addition: {a} + {b} = {self.add(a, b)}")
        print(f"Subtraction: {a} - {b} = {self.subtract(a, b)}")
        print(f"Multiplication: {a} × {b} = {self.multiply(a, b)}")
        print(f"Division: {a} ÷ {b} = {self.divide(a, b)}")
        print(f"Power: {a}^{b} = {self.power(a, b)}")

calc = Calculator()

calc.display_operations(10, 5)

print(f"\nIndividual operations:")
print(f"7 + 3 = {calc.add(7, 3)}")
print(f"7 - 3 = {calc.subtract(7, 3)}")
print(f"7 × 3 = {calc.multiply(7, 3)}")
print(f"7 ÷ 3 = {calc.divide(7, 3):.2f}")
print(f"2^4 = {calc.power(2, 4)}")

print(f"5 ÷ 0 = {calc.divide(5, 0)}")
# Out:
# Operations for 10 and 5:
# Addition: 10 + 5 = 15
# Subtraction: 10 - 5 = 5
# Multiplication: 10 × 5 = 50
# Division: 10 ÷ 5 = 2.0
# Power: 10^5 = 100000
#
# Individual operations:
# 7 + 3 = 10
# 7 - 3 = 4
# 7 × 3 = 21
# 7 ÷ 3 = 2.33
# 2^4 = 16
# 5 ÷ 0 = Error: Division by zero is not allowed
